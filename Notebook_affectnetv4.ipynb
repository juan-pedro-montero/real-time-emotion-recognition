# %% [markdown]
# # 1. Importación y configuración de entorno

# %% [markdown]
# ## Variables de entorno

# %%
# Directorio del dataset único: 
# Se asume que este directorio contiene carpetas, cada una con imágenes de una clase.
dataset_dir = r'.\archive'

# %% [markdown]
# ## Carga librerías

# %%
# Importamos las librerías esenciales de PyTorch y otras utilidades
import os
import random
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms, models
import dlib
import time
import shutil
from PIL import Image

import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

# %% [markdown]
# ## Selección de dispositivo

# %%
# Configuramos el dispositivo: usamos GPU si está disponible, sino se utiliza la CPU
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print("Usando dispositivo:", device)
# Out:
# Usando dispositivo: cuda:0

# %% [markdown]
# ## Semilla de reproducibilidad

# %%
# Establecemos una semilla para garantizar la reproducibilidad de los experimentos
seed = 42
random.seed(seed)
torch.manual_seed(seed)
if device.type == 'cuda':
    torch.cuda.manual_seed(seed)

# %% [markdown]
# ## Definición de hiperparámetros

# %%
# Hiperparámetros iniciales
BATCH_SIZE = 32      # Tamaño del batch para el entrenamiento
NUM_EPOCHS = 10      # Número de épocas (iteraciones completas sobre el dataset)
LEARNING_RATE = 1e-3 # Tasa de aprendizaje inicial
TRAIN_RATIO = 0.8    # Porcentaje de datos para entrenamiento (80% train, 20% valid)

# %% [markdown]
# ## Preprocesamiento de datos

# %%
# Directorio de salida para las imágenes recortadas
output_dir = './cropped_dataset'

# Crear el directorio de salida si no existe
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Inicializar el detector de caras de dlib
face_detector = dlib.get_frontal_face_detector()
i = 0
# Recorrer todas las subcarpetas e imágenes en el dataset original
for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        if file.lower().endswith(('.png', '.jpg', '.jpeg')):
            # Ruta completa de la imagen original
            img_path = os.path.join(root, file)
            
            # Leer la imagen
            img = Image.open(img_path).convert('RGB')
            img_np = np.array(img)
            
            # Detectar caras en la imagen
            faces = face_detector(img_np)
            
            # Si se detecta al menos una cara, recortar la primera
            if len(faces) > 0:
                face = faces[0]
                cropped_img = img.crop((face.left(), face.top(), face.right(), face.bottom()))
                
                # Crear la misma estructura de subcarpetas en el directorio de salida
                relative_path = os.path.relpath(root, dataset_dir)
                output_subdir = os.path.join(output_dir, relative_path)
                if not os.path.exists(output_subdir):
                    os.makedirs(output_subdir)
                
                # Guardar la imagen recortada
                cropped_img.save(os.path.join(output_subdir, file))
            else:
                print(f"No se detectaron caras en la imagen: {img_path}")
                i += 1
dataset_dir = output_dir
print(f"Se eliminaron {i} imágenes sin cara detectada.")
# Out:
# No se detectaron caras en la imagen: .\archive\anger\image0000060.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0000182.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0001527.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0002230.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0002340.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0002507.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0003455.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0003519.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0004698.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0005516.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0006167.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0006232.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0006322.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0006417.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0006816.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0008096.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0008631.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0009017.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0009177.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0009421.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0009534.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0009697.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0009812.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0010321.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0011283.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0011356.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0011826.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0011869.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0012119.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0012173.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0012248.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0012310.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0012330.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0012539.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0013071.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0013411.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0013485.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0013550.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0014003.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0014041.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0014526.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0014718.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0015605.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0015639.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0015695.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0015714.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0015819.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0016049.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0016157.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0016349.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0017069.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0017387.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0017536.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0017671.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0017731.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0017765.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0017803.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018428.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018493.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018506.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018606.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018704.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018854.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018868.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018905.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0018931.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019019.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019139.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019225.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019402.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019467.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019525.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019606.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019729.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019797.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019889.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0019896.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0020026.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0020036.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0020235.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0020437.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0020504.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0020793.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0020852.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0021140.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0021168.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0021266.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0021402.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0021678.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0021783.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0021821.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0022665.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0022676.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0023366.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0023428.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0023616.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0023665.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0023759.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0023821.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0023829.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0023934.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024032.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024153.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024175.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024316.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024378.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024410.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024636.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024669.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0024857.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0025141.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0025262.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0025374.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0025386.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0025485.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0025650.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0025678.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0025695.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026028.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026091.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026334.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026483.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026493.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026619.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026821.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026835.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026927.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0026956.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027224.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027308.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027453.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027500.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027583.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027616.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027628.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027662.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027687.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0027858.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0028095.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0028160.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0028344.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0028435.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0028597.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0028667.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029110.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029165.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029185.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029267.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029417.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029714.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029717.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029797.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029815.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029902.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0029990.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030048.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030121.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030284.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030289.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030407.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030477.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030632.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030668.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030719.jpg
# No se detectaron caras en la imagen: .\archive\anger\image0030722.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0004543.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0010819.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0015925.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0019359.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0020008.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0020913.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0021012.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0021653.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0024346.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0028147.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0029367.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0030871.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0030956.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0031051.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0031474.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0031626.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0032374.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0032729.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0032937.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0033874.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0034591.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0035070.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0035308.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0035834.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0035881.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0036037.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0036130.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0037204.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0037227.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0037801.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0038023.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0038091.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0038254.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0038366.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0038626.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0038749.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0038787.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0038979.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0039427.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0039802.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0039942.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0040557.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0040920.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0040965.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0041168.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0041263.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0041631.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0041683.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0042047.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image0042129.jpg
# No se detectaron caras en la imagen: .\archive\contempt\image10000099.jpg
# No se detectaron caras en la imagen: .\archive\disgust\ffhq_20.png
# No se detectaron caras en la imagen: .\archive\disgust\image0006914.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0006955.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0020561.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0022118.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0023502.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0023569.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0023867.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0027313.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0027371.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0028170.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0031315.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0031466.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0031964.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0032045.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0033334.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0034567.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0034857.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0035046.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0035065.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0035169.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0035171.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0035218.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0035656.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0036033.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0036214.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0036465.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0036712.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0037140.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0037381.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0037444.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0038289.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0038353.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0038790.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0038812.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0038835.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0039005.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0039669.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0039863.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0039976.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0040030.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0040129.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0040413.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0040773.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0040855.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0041189.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0041201.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0041298.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0041408.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0041745.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0041810.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0041918.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0042092.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0042142.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0042382.jpg
# No se detectaron caras en la imagen: .\archive\disgust\image0042448.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0003727.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0003845.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0011908.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0012116.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0012471.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0012488.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0012983.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0018155.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0018782.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0019036.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0019321.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0019672.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0020186.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0020482.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0020778.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0021624.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0023315.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0023570.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0023638.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0023727.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0023767.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0024430.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0024848.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0024934.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0025492.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0025663.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0025971.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0025993.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0026048.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0026103.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0027331.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0027370.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0027505.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0028014.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0028153.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0028352.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0028571.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0029038.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0029161.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0029287.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0029500.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0029661.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0029809.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0029842.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0029935.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0030153.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0030607.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0030924.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0030926.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031103.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031359.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031392.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031409.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031418.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031444.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031577.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031802.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0031921.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0032273.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0032566.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0032701.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0032777.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0032821.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0032832.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0032880.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0032956.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033220.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033240.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033348.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033351.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033355.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033555.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033572.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033681.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033813.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033867.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033904.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0033953.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034130.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034254.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034491.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034556.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034609.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034629.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034707.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034726.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0034810.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0035175.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0035251.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0035359.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0035388.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0035453.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0035599.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0035652.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0035863.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036097.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036129.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036192.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036285.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036309.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036353.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036452.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036459.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036606.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036695.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036775.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036793.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036811.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0036892.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037036.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037056.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037083.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037112.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037173.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037210.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037215.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037309.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037340.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037471.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037531.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037646.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037707.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037754.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037796.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037837.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0037867.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038027.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038074.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038095.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038143.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038193.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038280.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038306.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038389.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038461.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038470.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038544.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038574.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038616.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038629.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038666.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038669.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038672.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038742.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038778.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038860.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038889.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038944.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038953.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0038956.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039016.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039095.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039238.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039350.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039380.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039647.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039767.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039806.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039817.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039885.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0039973.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040017.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040026.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040073.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040106.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040132.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040221.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040265.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040295.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040334.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040363.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040425.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040470.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040475.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040486.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040507.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040565.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040614.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040725.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040764.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040810.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040823.jpg
# No se detectaron caras en la imagen: .\archive\fear\image0040953.jpg
# No se detectaron caras en la imagen: .\archive\happy\ffhq_1383.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_1453.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_2376.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_2415.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_2800.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_2823.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_3086.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_337.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_3390.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_3934.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_3990.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_4004.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_484.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_503.png
# No se detectaron caras en la imagen: .\archive\happy\ffhq_653.png
# No se detectaron caras en la imagen: .\archive\happy\image0032375.jpg
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_110.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_125.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_1339.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_1345.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_1459.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_1836.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_1873.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_1940.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_2185.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_2372.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_2692.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_2963.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_2979.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_315.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_368.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_3739.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_3940.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_4071.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_41.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_4285.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_4355.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_4591.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_4760.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_5336.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_5527.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_5588.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_800.png
# No se detectaron caras en la imagen: .\archive\neutral\ffhq_835.png
# No se detectaron caras en la imagen: .\archive\neutral\image0015262.jpg
# No se detectaron caras en la imagen: .\archive\neutral\image0031608.jpg
# No se detectaron caras en la imagen: .\archive\neutral\image9999989.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0000290.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0001037.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0001320.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0001602.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0001800.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0001850.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0001853.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0002040.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0002210.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0002792.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0003102.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0003253.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0003774.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0004052.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0004115.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0005593.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0005698.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0005884.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0005909.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0006231.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0006444.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0007279.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0007337.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0008148.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0008262.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0008926.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0009051.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0009422.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0009547.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0009784.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0009856.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0010065.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0010407.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0010654.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0011175.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0011546.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0011700.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0011992.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0012446.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0012459.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0012492.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0012793.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0013656.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0013755.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0013832.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0014052.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0014196.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0014327.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0014841.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0015143.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0015853.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0015854.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0016317.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0016555.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0016594.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0017194.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0017281.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0017624.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0017657.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0017734.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018053.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018166.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018257.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018266.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018308.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018396.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018410.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018416.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018681.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018768.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018771.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0018837.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0019155.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0019419.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0019742.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020014.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020054.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020083.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020107.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020378.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020432.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020548.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020575.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020683.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020740.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020959.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0020997.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0021104.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0021281.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0021424.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0021481.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0021686.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0021786.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0022089.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0022119.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0022164.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0022221.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0022349.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0023097.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0023135.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0023295.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0023559.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0023565.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0023760.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0024030.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0024036.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0024530.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0024767.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0024883.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0024884.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0024896.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0024905.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0025424.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0025524.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0025588.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0025648.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0026162.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0026339.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0026383.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0026711.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0026727.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0026740.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0026900.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0026957.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027027.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027385.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027432.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027441.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027493.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027602.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027751.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027758.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027833.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027835.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0027940.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028127.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028179.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028270.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028278.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028430.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028530.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028575.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028603.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028610.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028735.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0028978.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029115.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029204.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029229.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029250.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029536.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029567.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029704.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029777.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029934.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0029945.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0030041.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0030056.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0030066.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0030145.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0030175.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0030198.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0030356.jpg
# No se detectaron caras en la imagen: .\archive\sad\image0030485.jpg
# No se detectaron caras en la imagen: .\archive\surprise\ffhq_172.png
# No se detectaron caras en la imagen: .\archive\surprise\ffhq_286.png
# No se detectaron caras en la imagen: .\archive\surprise\ffhq_442.png
# No se detectaron caras en la imagen: .\archive\surprise\ffhq_62.png
# No se detectaron caras en la imagen: .\archive\surprise\image0000139.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0000152.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0000592.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0000805.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0003158.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0003571.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0003636.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0003752.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0004293.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0004544.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0004577.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0006778.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0007120.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0008945.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0009814.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0011075.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0011447.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0012430.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0012493.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0012577.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0012758.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0013067.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0013603.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0013704.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0014193.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0015288.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0015650.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0016205.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0017268.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0017285.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0017470.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0017728.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0018549.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0018624.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0018642.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0020334.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0021020.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0022084.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0022205.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0022684.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0023063.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0023190.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0023465.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0023545.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0023613.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0025042.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0025391.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0026270.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0026757.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0027028.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0027098.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0027326.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0027409.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0027645.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0027938.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0028082.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0028118.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0028140.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0028314.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0028545.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0029218.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0029634.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0029669.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0029794.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0030756.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0030800.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031022.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031054.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031066.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031071.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031318.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031394.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031499.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031517.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031582.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031668.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031698.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031862.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031871.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031920.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0031923.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0032317.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0032602.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0032676.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0032694.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0032806.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0033246.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0033316.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0033741.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0033752.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0033878.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034019.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034042.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034303.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034396.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034503.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034508.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034547.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034590.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034627.jpg
# No se detectaron caras en la imagen: .\archive\surprise\image0034642.jpg
# Se eliminaron 771 imágenes sin cara detectada.

# %% [markdown]
# Aqui hemos applicado un preprocesamiento de los imagenes con la deteccion facial que se usa en el entorno de produccion. En este caso, se esta haciendo cropping de la imagen para que el modelo no tenga que aprender a detectar la cara. Esto es un paso importante ya que el modelo no tiene que aprender a detectar la cara y puede concentrarse en aprender a clasificar las emociones.

# %%
# Mostramos la estructura del dataset (lista de clases) para verificar la organización
dataset_full = datasets.ImageFolder(root=dataset_dir, transform=transforms.ToTensor())
print("Clases encontradas en el dataset:", dataset_full.classes)
# Out:
# Clases encontradas en el dataset: ['anger', 'contempt', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %% [markdown]
# # 2. Transformaciones, Preprocesamiento y Data Augmentation

# %%
# Definimos las transformaciones para el conjunto de entrenamiento, enfocadas en simular condiciones reales de una cámara web en una consulta online.
train_transforms = transforms.Compose([
    # Si la imagen está en escala de grises, se convierte a 3 canales replicando el mismo canal
    transforms.Grayscale(num_output_channels=3),    
    
    # RandomResizedCrop simula un zoom in/out al recortar aleatoriamente la imagen y redimensionarla a 224x224,
    # permitiendo que el modelo se adapte a variaciones en la distancia entre la cámara y el usuario.
    transforms.RandomResizedCrop(224, scale=(0.8, 1.2)),
    
    # RandomHorizontalFlip simula la inversión lateral, ya que la posición o inclinación de la cabeza puede variar.
    transforms.RandomHorizontalFlip(p=0.5),
    
    # RandomRotation simula leves inclinaciones de la cabeza; se limita a 15° para que la rotación sea realista.
    transforms.RandomRotation(degrees=15),
    
    # ColorJitter ajusta brillo, contraste, saturación y tono, simulando diferentes condiciones de iluminación comunes en cámaras web.
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    
    # RandomAffine con translate y scale simula pequeñas translaciones y escalados, representando variaciones en el encuadre y posicionamiento del rostro.
    # Se evita rotación aquí ya que ya se cubrió con RandomRotation.
    transforms.RandomAffine(degrees=0, translate=(0.1, 0.1), scale=(0.9, 1.1)),
    
    # Convierte la imagen PIL a un tensor y escala los valores de píxel al rango [0, 1].
    transforms.ToTensor(),
    
    # Normaliza la imagen utilizando las medias y desviaciones estándar de ImageNet,
    # para que la distribución de entrada sea compatible con MobileNetV2 preentrenado.
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std=[0.229, 0.224, 0.225])
])

# Definimos las transformaciones para el conjunto de validación.
# Aquí se aplica solo el redimensionado y la normalización para mantener la consistencia,
# ya que en validación no queremos aplicar data augmentation.
val_transforms = transforms.Compose([
    transforms.Resize((224, 224)),  # Redimensiona la imagen a 224x224 píxeles.
    transforms.ToTensor(),          # Convierte la imagen a tensor escalado entre 0 y 1.
    transforms.Normalize(mean=[0.485, 0.456, 0.406],  # Aplica la normalización con parámetros de ImageNet.
                         std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# # 3. División del dataset

# %% [markdown]
# # Cargas el dataset completo sin transform

# %%
# Cargar el dataset completo (sin aplicar transformaciones aquí).
full_dataset = datasets.ImageFolder(
    root=dataset_dir, 
    transform=None  # Se aplicará transform más adelante según el subset (train/val).
)

# %% [markdown]
# # División del dataset en entrenamiento y validación

# %%
# Cálculo del número total de muestras y división en proporciones (p.ej., 80/20).
dataset_size = len(full_dataset)
train_size = int(TRAIN_RATIO * dataset_size)
val_size = dataset_size - train_size

# Dividimos el dataset con random_split (usando la semilla para reproducibilidad).
train_dataset, val_dataset = random_split(
    full_dataset,
    [train_size, val_size],
    generator=torch.Generator().manual_seed(seed)
)

print(f"Total de imágenes: {dataset_size}  ->  Train: {train_size}, Validation: {val_size}")
# Out:
# Total de imágenes: 30231  ->  Train: 24184, Validation: 6047

# %%
# Asignamos transformaciones a cada subset según corresponda (esto para evitar errores al lanzar el modelo con el random)
# (train_transforms y val_transforms se definieron en el Paso 2).
train_dataset.dataset.transform = train_transforms
val_dataset.dataset.transform   = val_transforms

# %% [markdown]
# Con este ajuste, todas las imágenes del conjunto de entrenamiento y validación se redimensionarán a 224×224, evitando el problema de dimensiones distintas que causaba el error al hacer batching.

# %% [markdown]
# # Creación de dataloaders

# %%
# Creamos DataLoaders para entrenar y validar
# Notar que no se especifica 'shuffle' en el conjunto de validación.
train_loader = DataLoader(
    train_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=True, 
    num_workers=2
)
val_loader = DataLoader(
    val_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=False, 
    num_workers=2
)

# Confirmamos la detección de clases en el dataset completo.
print("Clases detectadas en el dataset (orden interno):", full_dataset.classes)
# Out:
# Clases detectadas en el dataset (orden interno): ['anger', 'contempt', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %% [markdown]
# # 4. Modelo Preentrenado y Congelación de Capas

# %% [markdown]
# Este bloque de código se encargará de cargar MobileNetV2 con pesos preentrenados en ImageNet, enviar el modelo al dispositivo (CPU o GPU) y congelar sus capas base para que, en el entrenamiento inicial, solo se actualicen las nuevas capas que añadiremos posteriormente (en el siguiente bloque).

# %%
# Importamos el modelo MobileNetV2 desde torchvision.models.
# En versiones recientes de PyTorch se recomienda utilizar el argumento 'weights'
# para indicar que se carguen los pesos preentrenados de ImageNet.
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights

# Cargamos el modelo con los pesos preentrenados.
# Esto asegura que el modelo ya tiene conocimientos generales de características visuales.
model = mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1)

# Enviamos el modelo al dispositivo definido (GPU si está disponible, de lo contrario CPU)
model = model.to(device)

# Congelamos todas las capas base para que sus pesos no sean actualizados durante el entrenamiento inicial.
# Esto significa que, en este primer paso de transfer learning, solo se entrenará la nueva capa de clasificación.
for param in model.parameters():
    param.requires_grad = False

print("MobileNetV2 cargado y capas base congeladas.")
# Out:
# MobileNetV2 cargado y capas base congeladas.

# %%
print(model)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# # 5. Reemplazo capa final

# %% [markdown]
# La capa final de MobileNetV2 es parte de 'model.classifier'.
# Normalmente, esta parte consta de un Dropout, y una capa lineal. Necesitamos modificar la capa lineal para que tenga NUM_CLASSES salidas.

# %%
# Número de clases: ['anger', 'contempt', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']
NUM_CLASSES = 8  

# Extraemos el número de características de entrada de la última capa original.
in_features = model.classifier[1].in_features

# Reemplazamos la última capa (la capa de clasificación) con una nueva capa lineal que tenga la salida adecuada.
model.classifier[1] = torch.nn.Linear(in_features, NUM_CLASSES)

# Una vez reemplazada la capa, aseguramos que el modelo se envíe al dispositivo (CPU o GPU)
model = model.to(device)

# Imprimimos la parte modificada para verificar que la nueva capa se ha incorporado correctamente.
print("Estructura de la parte final del modelo modificada:")
print(model.classifier)
# Out:
# Estructura de la parte final del modelo modificada:
# Sequential(
#   (0): Dropout(p=0.2, inplace=False)
#   (1): Linear(in_features=1280, out_features=8, bias=True)
# )

# %% [markdown]
# # 6. Definición de pérdida y Optimizador

# %%
# Se define la función de pérdida para un problema de clasificación multiclase.
# CrossEntropyLoss combina log_softmax y la pérdida de entropía cruzada, lo que es ideal para este tipo de problemas.
criterion = nn.CrossEntropyLoss()

# Configuramos el optimizador; en este caso utilizamos Adam.
# Como estamos en la etapa inicial de transfer learning y solo queremos actualizar la nueva capa de clasificación,
# se pasan como parámetros únicamente los que pertenecen a model.classifier[1].
optimizer = optim.Adam(model.classifier[1].parameters(), lr=LEARNING_RATE)

print("Función de pérdida y optimizador configurados correctamente.")
# Out:
# Función de pérdida y optimizador configurados correctamente.

# %% [markdown]
# # 7. Entrenamiento Inicial (Frozen)

# %%
# Definimos las funciones de entrenamiento y validación
def train_one_epoch(model, dataloader, optimizer, criterion, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for inputs, targets in dataloader:
        inputs, targets = inputs.to(device), targets.to(device)
        
        # Forward
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        
        # Backprop
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == targets).sum().item()
        total += targets.size(0)
        
    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total
    return epoch_loss, epoch_acc

def validate_one_epoch(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for inputs, targets in dataloader:
            inputs, targets = inputs.to(device), targets.to(device)
            
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            
            running_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            correct += (predicted == targets).sum().item()
            total += targets.size(0)
    
    epoch_loss = running_loss / total
    epoch_acc = 100.0 * correct / total
    return epoch_loss, epoch_acc

# %% [markdown]
# # 8. Fine-Tuning (Descongelar Capas Seleccionadas)

# %% [markdown]
# 1. Descongelar Capas Seleccionadas:
#
# - Recorremos las últimas 3 capas dentro de model.features utilizando for param in model.features[-3:].parameters(): y establecemos param.requires_grad = True. Esto permite que, durante el fine-tuning, los pesos de estas capas se ajusten a tu dataset.
#
# - Imprimimos un mensaje para confirmar que se han descongelado las capas.
#
# 2. reación de Optimizer para Fine-Tuning:
#
# - Recorremos todos los parámetros de model y agregamos aquellos que tienen requires_grad = True a la lista params_to_update.
#
# - Creamos un nuevo optimizador (en este caso, Adam) con un learning rate reducido (1e-4) para realizar el ajuste fino. Un learning rate menor suele ser recomendable en esta fase para no alterar bruscamente los pesos preentrenados.
#
# 3. Bucle de Fine-Tuning:
#
# - Definimos cuántas épocas realizaremos en esta fase de fine-tuning (en el ejemplo, 5 épocas).
#
# - Dentro del bucle de fine-tuning, se utilizan las funciones train_one_epoch y validate_one_epoch (ya definidas) para actualizar el modelo y evaluar su rendimiento.
#
# - Se imprime la pérdida y precisión en cada época para monitorear la mejora del modelo.

# %%
# --------------------------------------------
# Fase Fine-Tuning: Descongelado de capas, entrenamiento y guardado del mejor modelo
# --------------------------------------------

# Descongelamos las últimas 3 capas del bloque de features de MobileNetV2 para fine-tuning.
for param in model.features[-5:].parameters():
    param.requires_grad = True
print("Las últimas 5 capas de model.features se han descongelado para fine-tuning.")

# Creamos un optimizador nuevo que actualice sólo los parámetros que tienen requires_grad=True,
# es decir, la nueva capa de clasificación y las capas recientemente descongeladas.
params_to_update = [param for name, param in model.named_parameters() if param.requires_grad]
fine_tune_optimizer = optim.Adam(params_to_update, lr=1e-4)  # Learning rate menor para fine-tuning

# Definimos el número de épocas para el fine-tuning
FINE_TUNE_EPOCHS = 20

# 4. Inicializamos listas para almacenar la evolución de loss y accuracy durante fine-tuning.
ft_train_loss_history = []
ft_train_acc_history = []
ft_val_loss_history   = []
ft_val_acc_history    = []

# Inicializamos el criterio para guardar el mejor modelo según la precisión de validación
best_val_acc = 0.0
PATH_BEST_FINE_TUNE = "best_model_finetuned_affectnet_v4.pt"

# (Opcional) Parámetros para early stopping en fine-tuning:
patience = 5       # Número de épocas sin mejora antes de detener el fine-tuning
epochs_no_improve = 0

print("Inicio del Fine-Tuning:")
for epoch in range(FINE_TUNE_EPOCHS):
    # Entrenamiento en la época actual usando el optimizador de fine-tuning.
    train_loss, train_acc = train_one_epoch(model, train_loader, fine_tune_optimizer, criterion, device)
    # Evaluación en el conjunto de validación.
    val_loss, val_acc = validate_one_epoch(model, val_loader, criterion, device)
    
    # Almacenamos las métricas de la época para futuras gráficas.
    ft_train_loss_history.append(train_loss)
    ft_train_acc_history.append(train_acc)
    ft_val_loss_history.append(val_loss)
    ft_val_acc_history.append(val_acc)
    
    print(f"Fine-Tuning Epoch {epoch+1}/{FINE_TUNE_EPOCHS}: "
          f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}% || "
          f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.2f}%")
    
    # Guardamos el modelo si la precisión de validación mejora.
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), PATH_BEST_FINE_TUNE)
        print(f">>> Modelo (Fine-Tuning) guardado en la época {epoch+1} con Val Acc = {val_acc:.2f}%")
        epochs_no_improve = 0  # Reseteamos el contador ya que hubo mejora.
    else:
        epochs_no_improve += 1
    
    # (Opcional) Early Stopping: se finaliza el fine-tuning si no mejora la precisión de validación tras 'patience' épocas.
    if epochs_no_improve >= patience:
        print("Early stopping activado en Fine-Tuning. Finalizando entrenamiento.")
        break
# Out:
# Las últimas 5 capas de model.features se han descongelado para fine-tuning.
# Inicio del Fine-Tuning:
# Fine-Tuning Epoch 1/20: Train Loss: 1.1572, Train Acc: 55.94% || Val Loss: 0.9477, Val Acc: 64.58%
# >>> Modelo (Fine-Tuning) guardado en la época 1 con Val Acc = 64.58%
# Fine-Tuning Epoch 2/20: Train Loss: 0.8824, Train Acc: 66.88% || Val Loss: 0.8902, Val Acc: 67.14%
# >>> Modelo (Fine-Tuning) guardado en la época 2 con Val Acc = 67.14%
# Fine-Tuning Epoch 3/20: Train Loss: 0.7479, Train Acc: 72.44% || Val Loss: 0.8883, Val Acc: 68.05%
# >>> Modelo (Fine-Tuning) guardado en la época 3 con Val Acc = 68.05%
# Fine-Tuning Epoch 4/20: Train Loss: 0.6252, Train Acc: 77.16% || Val Loss: 0.9472, Val Acc: 67.04%
# Fine-Tuning Epoch 5/20: Train Loss: 0.4906, Train Acc: 82.32% || Val Loss: 1.0252, Val Acc: 66.41%
# Fine-Tuning Epoch 6/20: Train Loss: 0.3648, Train Acc: 87.00% || Val Loss: 1.1277, Val Acc: 65.90%
# Fine-Tuning Epoch 7/20: Train Loss: 0.2575, Train Acc: 91.11% || Val Loss: 1.3047, Val Acc: 64.11%
# Fine-Tuning Epoch 8/20: Train Loss: 0.1856, Train Acc: 93.72% || Val Loss: 1.4093, Val Acc: 65.02%
# Early stopping activado en Fine-Tuning. Finalizando entrenamiento.

# %%
# Gráfica de Loss durante Fine-Tuning
plt.figure(figsize=(10, 6))
plt.plot(ft_train_loss_history, label='Fine-Tune Train Loss', marker='o')
plt.plot(ft_val_loss_history, label='Fine-Tune Val Loss', marker='o')
plt.title('Curva de Pérdida durante Fine-Tuning')
plt.xlabel('Épocas')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Gráfica de Accuracy durante Fine-Tuning
plt.figure(figsize=(10, 6))
plt.plot(ft_train_acc_history, label='Fine-Tune Train Acc', marker='o')
plt.plot(ft_val_acc_history, label='Fine-Tune Val Acc', marker='o')
plt.title('Curva de Precisión durante Fine-Tuning')
plt.xlabel('Épocas')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)

# %% [markdown]
# ## Evaluación y Métricas Adicionales (modelo fine tunning)

# %%
# Colocamos el modelo en modo evaluación (modelo tras fine-tuning)
model.eval()

# Acumulamos predicciones y etiquetas verdaderas del conjunto de validación
all_preds_ft = []
all_targets_ft = []
all_probs_ft = []  # Para la curva ROC

# Iniciamos el temporizador para medir el tiempo de inferencia
start_time = time.time()

with torch.no_grad():
    for inputs, targets in val_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        outputs = model(inputs)
        probs = torch.nn.functional.softmax(outputs, dim=1)
        _, preds = torch.max(outputs, 1)
        
        all_preds_ft.extend(preds.cpu().numpy())
        all_targets_ft.extend(targets.cpu().numpy())
        all_probs_ft.extend(probs.cpu().numpy())
# end time
end_time = time.time()
# Imprimimos el tiempo total de inferencia y el tempo promedio por imagen
print(f"Tiempo total de inferencia: {end_time - start_time:.2f} segundos")
print(f"Tiempo promedio por imagen: {(end_time - start_time) / len(val_loader.dataset):.4f} segundos")
# Matriz de Confusión
cm_ft = confusion_matrix(all_targets_ft, all_preds_ft)
plt.figure(figsize=(8,6))
sns.heatmap(cm_ft, annot=True, fmt='d', cmap="Blues",
            xticklabels=full_dataset.classes, yticklabels=full_dataset.classes)
plt.xlabel("Predicciones")
plt.ylabel("Etiquetas Verdaderas")
plt.title("Matriz de Confusión - Modelo Fine-Tuned")
plt.show()

# Reporte de Clasificación
print("Reporte de Clasificación - Modelo Fine-Tuned:\n")
print(classification_report(all_targets_ft, all_preds_ft, target_names=full_dataset.classes))

# Opcional: Curva ROC Multiclase para Modelo Fine-Tuned
all_probs_ft = np.array(all_probs_ft)
all_targets_ft = np.array(all_targets_ft)
y_true_bin_ft = label_binarize(all_targets_ft, classes=range(NUM_CLASSES))
n_classes = NUM_CLASSES

fpr_ft = dict()
tpr_ft = dict()
roc_auc_ft = dict()

for i in range(n_classes):
    fpr_ft[i], tpr_ft[i], _ = roc_curve(y_true_bin_ft[:, i], all_probs_ft[:, i])
    roc_auc_ft[i] = auc(fpr_ft[i], tpr_ft[i])

fpr_ft["micro"], tpr_ft["micro"], _ = roc_curve(y_true_bin_ft.ravel(), all_probs_ft.ravel())
roc_auc_ft["micro"] = auc(fpr_ft["micro"], tpr_ft["micro"])

plt.figure(figsize=(10,8))
plt.plot(fpr_ft["micro"], tpr_ft["micro"],
         label='Micro-average ROC curve (area = {0:0.2f})'.format(roc_auc_ft["micro"]),
         color='deeppink', linestyle=':', linewidth=4)
colors = ['aqua', 'darkorange', 'cornflowerblue', 'red', 'green', 'purple', 'brown', 'olive', 'cyan']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr_ft[i], tpr_ft[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.2f})'.format(full_dataset.classes[i], roc_auc_ft[i]))
plt.plot([0,1], [0,1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curva ROC Multiclase - Modelo Fine-Tuned')
plt.legend(loc="lower right")
plt.show()
# Out:
# Tiempo total de inferencia: 32.54 segundos
# Tiempo promedio por imagen: 0.0054 segundos
# Reporte de Clasificación - Modelo Fine-Tuned:
#
#               precision    recall  f1-score   support
#
#        anger       0.48      0.53      0.51       668
#     contempt       0.67      0.59      0.63       627
#      disgust       0.55      0.41      0.47       530
#         fear       0.51      0.53      0.52       654
#        happy       0.93      0.87      0.90      1069
#      neutral       0.81      0.86      0.83      1011
#          sad       0.47      0.57      0.52       654
#     surprise       0.58      0.56      0.57       834
#
#     accuracy                           0.65      6047
#    macro avg       0.62      0.62      0.62      6047
# weighted avg       0.66      0.65      0.65      6047
